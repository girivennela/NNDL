# %%
# necessary imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
df = pd.read_csv('Churn_Modelling.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# checking for null values

df.isna().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Assuming df is your DataFrame and Exited is a column in it
values = df.Exited.value_counts()
labels = ['Not Exited', 'Exited']

# Specify colors for each segment
colors = ['#FF9999', '#66B2FF']  # Custom colors for "Not Exited" and "Exited" segments

fig, ax = plt.subplots(figsize=(4, 3), dpi=100)
explode = (0, 0.09)

# Use the colors parameter to set custom colors
patches, texts, autotexts = ax.pie(values, labels=labels, autopct='%1.2f%%', shadow=True,
                                   startangle=90, explode=explode, colors=colors)

plt.setp(texts, color='grey')
plt.setp(autotexts, size=8, color='white')
autotexts[1].set_color('black')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


fig, ax = plt.subplots(3, 2, figsize=(18, 15))

# Set custom colors
colors = ['#66b3ff', '#99ff99']  # You can customize these colors

# Plotting different types of graphs with custom colors
sns.barplot(x='Geography', y='Exited', data=df, ax=ax[0][0], palette=colors)
sns.barplot(x='Gender', y='Exited', data=df, ax=ax[0][1], palette=colors)
sns.barplot(x='Tenure', y='Exited', data=df, ax=ax[1][0], palette=colors)
sns.barplot(x='NumOfProducts', y='Exited', data=df, ax=ax[1][1], palette=colors)
sns.barplot(x='HasCrCard', y='Exited', data=df, ax=ax[2][0], palette=colors)
sns.barplot(x='IsActiveMember', y='Exited', data=df, ax=ax[2][1], palette=colors)

# You can customize the layout further if needed
plt.tight_layout()
plt.show()

# %%
# visualizing continuous variables

fig, ax = plt.subplots(2, 2, figsize = (16, 10))

sns.boxplot(x = 'Exited', y = 'CreditScore', data = df, ax = ax[0][0])
sns.boxplot(x = 'Exited', y = 'Age', data = df, ax = ax[0][1])
sns.boxplot(x = 'Exited', y = 'Balance', data = df, ax = ax[1][0])
sns.boxplot(x = 'Exited', y = 'EstimatedSalary', data = df, ax = ax[1][1])

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 12))

# Exclude non-numeric columns
numeric_columns = df.select_dtypes(include=[np.number]).columns
corr = df[numeric_columns].corr()

# Set custom colors and use a diverging colormap
cmap = sns.diverging_palette(220, 20, as_cmap=True)

sns.heatmap(corr, linewidths=1, annot=True, fmt=".2f", cmap=cmap, square=True)

# You can customize the layout further if needed
plt.show()

# %%
# dropping uswanted columns

df.drop(columns = ['RowNumber', 'CustomerId', 'Surname'], axis = 1, inplace = True)
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df.Geography.value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
# Encoding categorical variables

df['Geography'] = df['Geography'].map({'France' : 0, 'Germany' : 1, 'Spain' : 2})
df['Gender'] = df['Gender'].map({'Male' : 0, 'Female' : 1})

# %%
df.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       1   42       2       0.00              1
# 1          608          2       1   41       1   83807.86              1
# 2          502          0       1   42       8  159660.80              3
# 3          699          0       1   39       1       0.00              2
# 4          850          2       1   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
# creating features and label
from tensorflow.keras.utils import to_categorical

X = df.drop('Exited', axis=1)
y = to_categorical(df.Exited)

# Assuming you're using TensorFlow 2.x
from tensorflow.compat.v1.losses import sparse_softmax_cross_entropy

# %%
# splitting data into training set and test set

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %%
# Scaling data

from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import BatchNormalization

# initializing ann
model = Sequential()

# adding the first input layer and the first hidden layer
model.add(Dense(10, kernel_initializer = 'normal', activation = 'relu', input_shape = (10, )))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the third hidden layer
model.add(Dense(7, kernel_initializer = 'normal', activation = 'relu'))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.1))
model.add(BatchNormalization())

# adding the output layer
model.add(Dense(2, kernel_initializer = 'normal', activation = 'sigmoid'))

# compiling the model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# fitting the model to the training set

model_history = model.fit(X_train, y_train, validation_split = 0.20, validation_data = (X_test, y_test), epochs = 100)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 2s 4ms/step - loss: 0.5965 - accuracy: 0.6987 - val_loss: 0.5343 - val_accuracy: 0.7948
# Epoch 2/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4290 - accuracy: 0.8292 - val_loss: 0.4197 - val_accuracy: 0.8180
# Epoch 3/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3942 - accuracy: 0.8360 - val_loss: 0.3777 - val_accuracy: 0.8464
# Epoch 4/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3833 - accuracy: 0.8400 - val_loss: 0.3795 - val_accuracy: 0.8456
# Epoch 5/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3809 - accuracy: 0.8415 - val_loss: 0.3761 - val_accuracy: 0.8424
# Epoch 6/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.3746 - accuracy: 0.8417 - val_loss: 0.3697 - val_accuracy: 0.8468
# Epoch 7/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3742 - accuracy: 0.8443 - val_loss: 0.3736 - val_accuracy: 0.8476
# Epoch 8/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3757 - accuracy: 0.8421 - val_loss: 0.3636 - val_accuracy: 0.8520
# Epoch 9/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3693 - accuracy: 0.8483 - val_loss: 0.3692 - val_accuracy: 0.8504
# Epoch 10/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.
100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3600 - accuracy: 0.8468 - val_loss: 0.3622 - val_accuracy: 0.8536
# Epoch 84/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3603 - accuracy: 0.8516 - val_loss: 0.3615 - val_accuracy: 0.8552
# Epoch 85/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3648 - accuracy: 0.8476 - val_loss: 0.3613 - val_accuracy: 0.8536
# Epoch 86/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3614 - accuracy: 0.8505 - val_loss: 0.3630 - val_accuracy: 0.8544
# Epoch 87/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3580 - accuracy: 0.8493 - val_loss: 0.3601 - val_accuracy: 0.8544
# Epoch 88/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3633 - accuracy: 0.8473 - val_loss: 0.3607 - val_accuracy: 0.8552
# Epoch 89/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.3576 - accuracy: 0.8536 - val_loss: 0.3595 - val_accuracy: 0.8552
# Epoch 90/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.3603 - accuracy: 0.8445 - val_loss: 0.3603 - val_accuracy: 0.8576
# Epoch 91/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3631 - accuracy: 0.8493 - val_loss: 0.3638 - val_accuracy: 0.8524
# Epoch 92/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3612 - accuracy: 0.8497 - val_loss: 0.3615 - val_accuracy: 0.8568
# Epoch 93/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3606 - accuracy: 0.8479 - val_loss: 0.3613 - val_accuracy: 0.8552
# Epoch 94/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3616 - accuracy: 0.8493 - val_loss: 0.3596 - val_accuracy: 0.8544
# Epoch 95/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3588 - accuracy: 0.8519 - val_loss: 0.3629 - val_accuracy: 0.8540
# Epoch 96/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3568 - accuracy: 0.8523 - val_loss: 0.3629 - val_accuracy: 0.8516
# Epoch 97/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3619 - accuracy: 0.8515 - val_loss: 0.3609 - val_accuracy: 0.8528
# Epoch 98/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3627 - accuracy: 0.8487 - val_loss: 0.3609 - val_accuracy: 0.8532
# Epoch 99/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3569 - accuracy: 0.8527 - val_loss: 0.3621 - val_accuracy: 0.8564
# Epoch 100/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.3623 - accuracy: 0.8501 - val_loss: 0.3619 - val_accuracy: 0.8540

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

train_loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epoch = range(1, 101)


sns.lineplot(x=epoch, y=train_loss, label='Training Loss', linestyle='-', linewidth=2, color='blue')
sns.lineplot(x=epoch, y=val_loss, label='Validation Loss', linestyle='--', linewidth=2, color='orange')

plt.title('Training and Validation Loss\n')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)  # Add grid lines for better readability

# You can customize the layout further if needed
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

train_accuracy = model_history.history['accuracy']
val_accuracy = model_history.history['val_accuracy']
epoch = range(1, 101)
sns.lineplot(x=epoch, y=train_accuracy, label='Training Accuracy', linestyle='-', linewidth=2, color='green')
sns.lineplot(x=epoch, y=val_accuracy, label='Validation Accuracy', linestyle='--', linewidth=2, color='purple')

plt.title('Training and Validation Accuracy\n')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)  # Add grid lines for better readability

# You can customize the layout further if needed
plt.show()

# %%
acc = model.evaluate(X_test, y_test)[1]

print(f'Accuracy of model is {acc}')
# Out:
# 79/79 [==============================] - 0s 2ms/step - loss: 0.3619 - accuracy: 0.8540
# Accuracy of model is 0.8539999723434448

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                110
#
#  dropout (Dropout)           (None, 10)                0
#
#  batch_normalization (Batch  (None, 10)                40
#  Normalization)
#
#  dense_1 (Dense)             (None, 7)                 77
#
#  dropout_1 (Dropout)         (None, 7)                 0
#
#  batch_normalization_1 (Bat  (None, 7)                 28
#  chNormalization)
#
#  dense_2 (Dense)             (None, 2)                 16
#
# =================================================================
# Total params: 271 (1.06 KB)
# Trainable params: 237 (948.00 Byte)
# Non-trainable params: 34 (136.00 Byte)
# _________________________________________________________________

# %%
model = Sequential()

# adding the first input layer and the first hidden layer
model.add(Dense(10, kernel_initializer = 'normal', activation = 'relu', input_shape = (10, )))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.6))
model.add(BatchNormalization())

# adding the third hidden layer
model.add(Dense(7, kernel_initializer = 'normal', activation = 'relu'))

# adding batch normalization and dropout layer
model.add(Dropout(rate = 0.6))
model.add(BatchNormalization())

# adding the output layer
model.add(Dense(2, kernel_initializer = 'normal', activation = 'sigmoid'))

# compiling the model
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# fitting the model to the training set

model_history = model.fit(X_train, y_train, validation_split = 0.20, validation_data = (X_test, y_test), epochs = 100)
# Out:
# Epoch 1/100
# 235/235 [==============================] - 6s 11ms/step - loss: 0.6405 - accuracy: 0.7251 - val_loss: 0.5712 - val_accuracy: 0.7948
# Epoch 2/100
# 235/235 [==============================] - 2s 10ms/step - loss: 0.5156 - accuracy: 0.7883 - val_loss: 0.4728 - val_accuracy: 0.7948
# Epoch 3/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.4805 - accuracy: 0.7951 - val_loss: 0.4598 - val_accuracy: 0.7948
# Epoch 4/100
# 235/235 [==============================] - 2s 7ms/step - loss: 0.4724 - accuracy: 0.7955 - val_loss: 0.4536 - val_accuracy: 0.7948
# Epoch 5/100
# 235/235 [==============================] - 2s 8ms/step - loss: 0.4678 - accuracy: 0.7952 - val_loss: 0.4508 - val_accuracy: 0.7948
# Epoch 6/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4698 - accuracy: 0.7948 - val_loss: 0.4465 - val_accuracy: 0.7948
# Epoch 7/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4698 - accuracy: 0.7936 - val_loss: 0.4475 - val_accuracy: 0.7948
# Epoch 8/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4611 - accuracy: 0.7969 - val_loss: 0.4361 - val_accuracy: 0.7960
# Epoch 9/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.
100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4532 - accuracy: 0.8013 - val_loss: 0.4216 - val_accuracy: 0.8148
# Epoch 78/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4602 - accuracy: 0.7997 - val_loss: 0.4231 - val_accuracy: 0.8144
# Epoch 79/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4547 - accuracy: 0.8019 - val_loss: 0.4291 - val_accuracy: 0.8052
# Epoch 80/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4516 - accuracy: 0.8019 - val_loss: 0.4254 - val_accuracy: 0.8108
# Epoch 81/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4562 - accuracy: 0.8029 - val_loss: 0.4199 - val_accuracy: 0.8128
# Epoch 82/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4530 - accuracy: 0.7997 - val_loss: 0.4234 - val_accuracy: 0.8096
# Epoch 83/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4507 - accuracy: 0.8040 - val_loss: 0.4215 - val_accuracy: 0.8100
# Epoch 84/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4540 - accuracy: 0.8009 - val_loss: 0.4229 - val_accuracy: 0.8072
# Epoch 85/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4546 - accuracy: 0.7997 - val_loss: 0.4213 - val_accuracy: 0.8076
# Epoch 86/100
# 235/235 [==============================] - 1s 5ms/step - loss: 0.4589 - accuracy: 0.7997 - val_loss: 0.4223 - val_accuracy: 0.8084
# Epoch 87/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4581 - accuracy: 0.8011 - val_loss: 0.4209 - val_accuracy: 0.8072
# Epoch 88/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4612 - accuracy: 0.7980 - val_loss: 0.4187 - val_accuracy: 0.8108
# Epoch 89/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4561 - accuracy: 0.8008 - val_loss: 0.4231 - val_accuracy: 0.8096
# Epoch 90/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4558 - accuracy: 0.8004 - val_loss: 0.4228 - val_accuracy: 0.8096
# Epoch 91/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4543 - accuracy: 0.8005 - val_loss: 0.4223 - val_accuracy: 0.8092
# Epoch 92/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4560 - accuracy: 0.8032 - val_loss: 0.4247 - val_accuracy: 0.8056
# Epoch 93/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4506 - accuracy: 0.8048 - val_loss: 0.4220 - val_accuracy: 0.8060
# Epoch 94/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4557 - accuracy: 0.8041 - val_loss: 0.4218 - val_accuracy: 0.8088
# Epoch 95/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4549 - accuracy: 0.8033 - val_loss: 0.4215 - val_accuracy: 0.8080
# Epoch 96/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4588 - accuracy: 0.8004 - val_loss: 0.4248 - val_accuracy: 0.8104
# Epoch 97/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4551 - accuracy: 0.8029 - val_loss: 0.4240 - val_accuracy: 0.8072
# Epoch 98/100
# 235/235 [==============================] - 1s 3ms/step - loss: 0.4532 - accuracy: 0.8020 - val_loss: 0.4260 - val_accuracy: 0.8100
# Epoch 99/100
# 235/235 [==============================] - 1s 4ms/step - loss: 0.4561 - accuracy: 0.8011 - val_loss: 0.4264 - val_accuracy: 0.8080
# Epoch 100/100
# 235/235 [==============================] - 1s 6ms/step - loss: 0.4515 - accuracy: 0.8008 - val_loss: 0.4262 - val_accuracy: 0.8084

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

train_loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epoch = range(1, 101)
sns.lineplot(x=epoch, y=train_loss, label='Training Loss', linestyle='-', linewidth=2, color='red')
sns.lineplot(x=epoch, y=val_loss, label='Validation Loss', linestyle='--', linewidth=2, color='blue')

plt.title('Training and Validation Loss\n')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)  # Add grid lines for better readability

# You can customize the layout further if needed
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

train_accuracy = model_history.history['accuracy']
val_accuracy = model_history.history['val_accuracy']
epoch = range(1, 101)

sns.lineplot(x=epoch, y=train_accuracy, label='Training Accuracy', linestyle='-', linewidth=2, color='green')
sns.lineplot(x=epoch, y=val_accuracy, label='Validation Accuracy', linestyle='--', linewidth=2, color='purple')

plt.title('Training and Validation Accuracy\n')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)  # Add grid lines for better readability

plt.show()

# %%
acc = model.evaluate(X_test, y_test)[1]

print(f'Accuracy of model is {acc}')
# Out:
# 79/79 [==============================] - 0s 2ms/step - loss: 0.4262 - accuracy: 0.8084
# Accuracy of model is 0.8083999752998352

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 10)                110
#
#  dropout_2 (Dropout)         (None, 10)                0
#
#  batch_normalization_2 (Bat  (None, 10)                40
#  chNormalization)
#
#  dense_4 (Dense)             (None, 7)                 77
#
#  dropout_3 (Dropout)         (None, 7)                 0
#
#  batch_normalization_3 (Bat  (None, 7)                 28
#  chNormalization)
#
#  dense_5 (Dense)             (None, 2)                 16
#
# =================================================================
# Total params: 271 (1.06 KB)
# Trainable params: 237 (948.00 Byte)
# Non-trainable params: 34 (136.00 Byte)
# _________________________________________________________________
